# %%
import pandas as pd# series type(1d) and dataframe(2d) data has its on way of handling
import numpy as np

# %%
dir(pd)
# Out:
# ['Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseDtype',
#  'SparseSeries',
#  'TimeGrouper',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_hashtable',
#  '_lib',
#  '_libs',
# ...

# %%
s =pd.Series(np.arange(10,15),list('abcde'))# index= row numbers
print(s)
print(s.size)
print(s.dtype)
print(s.itemsize)
# Out:
# a    10
# b    11
# c    12
# d    13
# e    14
# dtype: int32
# 5
# int32
# 4
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Series.itemsize is deprecated and will be removed in a future version
#   """

# %%
s =pd.Series(np.arange(10,15),list('abcde'))# index= row numbers
print(s)
print(s['b':])
print(s['c':])
print(s['a'])
print(s[:"c"])
print(s.loc['b'])
print(s.iloc[2:])
# Out:
# a    10
# b    11
# c    12
# d    13
# e    14
# dtype: int32
# b    11
# c    12
# d    13
# e    14
# dtype: int32
# c    12
# d    13
# e    14
# dtype: int32
# 10
# a    10
# b    11
# c    12
# dtype: int32
# 11
# c    12
# d    13
# e    14
# dtype: int32

# %%
df1 = pd.read_csv('titanic_dataset.csv')

# %%
# %pwd
# Out:
# 'C:\\Users\\Jaijo Johnson'

# %%
df1.head()
# Out:
#    Unnamed: 0  pclass  survived  \
# 0           0       1         1
# 1           1       1         1
# 2           2       1         0
# 3           3       1         0
# 4           4       1         0
#
#                                               name  gender      age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1                   Allison, Master. Hudson Trevor    male   0.9167      1
# 2                     Allison, Miss. Helen Loraine  female   2.0000      1
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000      1
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1
#
#    parch  ticket      fare    cabin embarked boat   body  \
# 0      0   24160  $211.34        B5        S    2    NaN
# 1      2  113781  $151.55   C22 C26        S   11    NaN
# 2      2  113781  $151.55   C22 C26        S  NaN    NaN
# 3      2  113781  $151.55   C22 C26        S  NaN  135.0
# ...

# %%
df1.describe(include = "all")
# Out:
#          Unnamed: 0       pclass     survived              name gender  \
# count   1309.000000  1309.000000  1309.000000              1309   1309
# unique          NaN          NaN          NaN              1307      2
# top             NaN          NaN          NaN  Kelly, Mr. James   male
# freq            NaN          NaN          NaN                 2    843
# mean     654.000000     2.294882     0.381971               NaN    NaN
# std      378.020061     0.837836     0.486055               NaN    NaN
# min        0.000000     1.000000     0.000000               NaN    NaN
# 25%      327.000000     2.000000     0.000000               NaN    NaN
# 50%      654.000000     3.000000     0.000000               NaN    NaN
# 75%      981.000000     3.000000     1.000000               NaN    NaN
# max     1308.000000     3.000000     1.000000               NaN    NaN
#
#                 age        sibsp        parch    ticket    fare        cabin  \
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'pclass', 'survived', 'name', 'gender', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body',
#        'home.dest'],
#       dtype='object')

# %%
df1.count
# Out:
# <bound method DataFrame.count of       Unnamed: 0  pclass  survived  \
# 0              0       1         1
# 1              1       1         1
# 2              2       1         0
# 3              3       1         0
# 4              4       1         0
# 5              5       1         1
# 6              6       1         1
# 7              7       1         0
# 8              8       1         1
# 9              9       1         0
# 10            10       1         0
# 11            11       1         1
# 12            12       1         1
# 13            13       1         1
# 14            14       1         1
# 15            15       1         0
# 16            16       1         0
# 17            17       1         1
# 18            18       1         1
# 19            19       1         0
# 20            20       1         1
# 21            21       1         1
# 22            22       1         1
# 23            23       1         1
# 24            24       1         1
# ...

# %%
df1.dtypes
# Out:
# Unnamed: 0      int64
# pclass          int64
# survived        int64
# name           object
# gender         object
# age           float64
# sibsp           int64
# parch           int64
# ticket         object
# fare           object
# cabin          object
# embarked       object
# boat           object
# body          float64
# home.dest      object
# dtype: object

# %%
df = pd.DataFrame(np.random.randint(100,150,40).reshape(10,4), columns=["A","B","C","D"])

# %%
df
# Out:
#      A    B    C    D
# 0  142  141  119  129
# 1  128  106  114  107
# 2  131  146  147  105
# 3  142  139  105  121
# 4  143  135  146  124
# 5  140  102  147  115
# 6  111  138  108  101
# 7  132  124  130  115
# 8  130  146  104  101
# 9  112  121  109  124

# %%
df.describe()
# Out:
#                A           B           C           D
# count   10.00000   10.000000   10.000000   10.000000
# mean   131.10000  129.800000  122.900000  114.200000
# std     11.73267   15.915052   18.052085   10.239358
# min    111.00000  102.000000  104.000000  101.000000
# 25%    128.50000  121.750000  108.250000  105.500000
# 50%    131.50000  136.500000  116.500000  115.000000
# 75%    141.50000  140.500000  142.000000  123.250000
# max    143.00000  146.000000  147.000000  129.000000

# %%
df.tail()
# Out:
#      A    B    C    D
# 5  140  102  147  115
# 6  111  138  108  101
# 7  132  124  130  115
# 8  130  146  104  101
# 9  112  121  109  124

# %%
print(df["A"])#columns
print(df.A)
print()
print(df[4:])#rows
print()
print(df.loc[0])
print(df.loc[0:3])
# Out:
# 0    142
# 1    128
# 2    131
# 3    142
# 4    143
# 5    140
# 6    111
# 7    132
# 8    130
# 9    112
# Name: A, dtype: int32
# 0    142
# 1    128
# 2    131
# 3    142
# 4    143
# 5    140
# 6    111
# 7    132
# 8    130
# 9    112
# Name: A, dtype: int32
#
#      A    B    C    D
# 4  143  135  146  124
# 5  140  102  147  115
# 6  111  138  108  101
# 7  132  124  130  115
# 8  130  146  104  101
# 9  112  121  109  124
#
# A    142
# B    141
# C    119
# D    129
# Name: 0, dtype: int32
#      A    B    C    D
# 0  142  141  119  129
# 1  128  106  114  107
# 2  131  146  147  105
# 3  142  139  105  121

# %%
print(df.loc[:,"B":])
print(df.loc[:5,:"C"])
# Out:
#      B    C    D
# 0  141  119  129
# 1  106  114  107
# 2  146  147  105
# 3  139  105  121
# 4  135  146  124
# 5  102  147  115
# 6  138  108  101
# 7  124  130  115
# 8  146  104  101
# 9  121  109  124
#      A    B    C
# 0  142  141  119
# 1  128  106  114
# 2  131  146  147
# 3  142  139  105
# 4  143  135  146
# 5  140  102  147

# %%
df['p']=pd.Series([1,2,3,4])

# %%
df
print(df.isna())
print(df.isna().any())# which colunms contains BLANK OR NaN values
# Out:
#        A      B      C      D      p
# 0  False  False  False  False  False
# 1  False  False  False  False  False
# 2  False  False  False  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False   True
# 5  False  False  False  False   True
# 6  False  False  False  False   True
# 7  False  False  False  False   True
# 8  False  False  False  False   True
# 9  False  False  False  False   True
# A    False
# B    False
# C    False
# D    False
# p     True
# dtype: bool

# %%
df.shape
# Out:
# (10, 5)

# %%
df1.shape
# Out:
# (1309, 15)

# %%
df1.isna().any()
# Out:
# Unnamed: 0    False
# pclass        False
# survived      False
# name          False
# gender        False
# age            True
# sibsp         False
# parch         False
# ticket        False
# fare           True
# cabin          True
# embarked       True
# boat           True
# body           True
# home.dest      True
# dtype: bool

# %%
df1.isna().sum()# how many data missing in a particular column
# Out:
# Unnamed: 0       0
# pclass           0
# survived         0
# name             0
# gender           0
# age            263
# sibsp            0
# parch            0
# ticket           0
# fare             1
# cabin         1014
# embarked         2
# boat           823
# body          1188
# home.dest      564
# dtype: int64

# %%
s =(df1.isna().sum())

# %%
df
# Out:
#      A    B    C    D    p
# 0  142  141  119  129  1.0
# 1  128  106  114  107  2.0
# 2  131  146  147  105  3.0
# 3  142  139  105  121  4.0
# 4  143  135  146  124  NaN
# 5  140  102  147  115  NaN
# 6  111  138  108  101  NaN
# 7  132  124  130  115  NaN
# 8  130  146  104  101  NaN
# 9  112  121  109  124  NaN

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
print(s/1309*100)
# Out:
# Unnamed: 0     0.000000
# pclass         0.000000
# survived       0.000000
# name           0.000000
# gender         0.000000
# age           20.091673
# sibsp          0.000000
# parch          0.000000
# ticket         0.000000
# fare           0.076394
# cabin         77.463713
# embarked       0.152788
# boat          62.872422
# body          90.756303
# home.dest     43.086325
# dtype: float64

# %%
df =df.drop(columns=['p'])

# %%
df
# Out:
#      A    B    C    D
# 0  142  141  119  129
# 1  128  106  114  107
# 2  131  146  147  105
# 3  142  139  105  121
# 4  143  135  146  124
# 5  140  102  147  115
# 6  111  138  108  101
# 7  132  124  130  115
# 8  130  146  104  101
# 9  112  121  109  124

# %%
df["P"] =df.sum(axis =1)

# %%
df
# Out:
#      A    B    C    D    P
# 0  142  141  119  129  531
# 1  128  106  114  107  455
# 2  131  146  147  105  529
# 3  142  139  105  121  507
# 4  143  135  146  124  548
# 5  140  102  147  115  504
# 6  111  138  108  101  458
# 7  132  124  130  115  501
# 8  130  146  104  101  481
# 9  112  121  109  124  466

# %%
r = df.iloc[:,2:]# slicing

# %%
r.sum(axis=1)
# Out:
# 0    1558
# 1    1352
# 2    1562
# 3    1466
# 4    1636
# 5    1532
# 6    1334
# 7    1492
# 8    1372
# 9    1398
# dtype: int64

# %%
df["Total"] = r.sum(axis=1)

# %%
df.Total.mean()
# Out:
# 1470.2

# %%
df = df.sort_values(by="Total",ascending =False)

# %%
df
# Out:
#      A    B    C    D    P  Total
# 4  143  135  146  124  548   1636
# 2  131  146  147  105  529   1562
# 0  142  141  119  129  531   1558
# 5  140  102  147  115  504   1532
# 7  132  124  130  115  501   1492
# 3  142  139  105  121  507   1466
# 9  112  121  109  124  466   1398
# 8  130  146  104  101  481   1372
# 1  128  106  114  107  455   1352
# 6  111  138  108  101  458   1334

# %%
# to create  a dataFrame containing 3 columns with 20rows.
#"A" : random numbers from 100-200#
#"B" : numbers  from 1-20
#"C": first 20 capital alphabets

# %%
df1 =pd.DataFrame()

# %%
import string
df1['A'] = np.random.randint(100,200,20)
df1['B'] = np.arange(1,21)
df1['C'] = [chr(x)for x in range(65,85)]

# %%
df1
# Out:
#       A   B  C
# 0   169   1  A
# 1   147   2  B
# 2   167   3  C
# 3   186   4  D
# 4   113   5  E
# 5   141   6  F
# 6   100   7  G
# 7   102   8  H
# 8   140   9  I
# 9   159  10  J
# 10  188  11  K
# 11  148  12  L
# 12  132  13  M
# 13  194  14  N
# 14  174  15  O
# 15  175  16  P
# 16  100  17  Q
# 17  123  18  R
# 18  123  19  S
# 19  199  20  T

# %%
df.A.value_counts()
# Out:
# 142    2
# 143    1
# 140    1
# 111    1
# 132    1
# 131    1
# 130    1
# 128    1
# 112    1
# Name: A, dtype: int64
